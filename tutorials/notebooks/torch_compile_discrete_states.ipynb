# %% [markdown]
# # torch.compile with `DiscreteStates`
#
# This short experiment shows that a `DiscreteStates` wrapper can safely flow through `torch.compile`. We instantiate a simple environment, grab its states/actions, and compare the eager and compiled results of a single `_step` call.

# %%
import torch
from gfn.gym.hypergrid import HyperGrid

# Resolve device (CUDA if available, else CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Instantiate a small environment and grab states/actions.
env = HyperGrid(ndim=2, height=4, device=device)
states = env.reset(batch_shape=4)
actions = env.actions_from_batch_shape((4,))
actions.tensor = torch.ones((4, 1), dtype=torch.long, device=device)

# Define a helper that takes raw tensors, rebuilds the wrappers, and returns the step result.
def step_once(states_tensor: torch.Tensor, actions_tensor: torch.Tensor) -> torch.Tensor:
    s = env.States(states_tensor)
    a = env.Actions(actions_tensor)
    return env._step(s, a).tensor

compiled_step = torch.compile(step_once, dynamic=True)

eager_out = step_once(states.tensor, actions.tensor)
compiled_out = compiled_step(states.tensor, actions.tensor)

print("Outputs match:", torch.equal(eager_out, compiled_out))
print("Output device:", compiled_out.device)
print("Example compiled output:\n", compiled_out)
# Out:
# Using device: cpu
# /Users/jdv/code/torchgfn/src/gfn/gym/hypergrid.py:90: UserWarning: + Warning: height <= 4 can lead to unsolvable environments.
#   warnings.warn("+ Warning: height <= 4 can lead to unsolvable environments.")
# /Users/jdv/code/torchgfn/src/gfn/env.py:495: UserWarning: You're using advanced parameters: (sf). These are only needed for custom action handling. For basic environments, you can omit these.
#   warnings.warn(
# [W1126 23:25:08.072794000 unwind.cpp:12] Warning: record_context_cpp is not support on non-linux non-x86_64 platforms (function operator())
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0] Graph break from `Tensor.item()`, consider setting:
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]     torch._dynamo.config.capture_scalar_outputs = True
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0] or:
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]     env TORCHDYNAMO_CAPTURE_SCALAR_OUTPUTS=1
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0] to include these operations in the captured graph.
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0] Graph break: from user code at:
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]   File "/Users/jdv/code/torchgfn/src/gfn/env.py", line 309, in torch_dynamo_resume_in__step_at_307
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]     if not self.is_action_valid(valid_states, valid_actions):
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]   File "/Users/jdv/code/torchgfn/src/gfn/env.py", line 643, in is_action_valid
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]     return bool(torch.gather(masks_tensor, 1, actions.tensor).all().item())
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]
# W1126 23:25:12.035000 80441 site-packages/torch/_dynamo/variables/tensor.py:1047] [9/0]
# Outputs match: True
# Output device: cpu
# Example compiled output:
#  tensor([[0, 1],
#         [0, 1],
#         [0, 1],
#         [0, 1]])

# %% [markdown]
# ## Microbenchmark harness
#
# The cells below build a small timing helper so we can compare `step_once` in eager mode vs the `torch.compile(..., dynamic=True)` variant under identical inputs. We run everything on CPU for consistency.

# %%
import math
import statistics
import warnings
from typing import Callable, Dict

import torch.utils.benchmark as benchmark


def _sync_if_needed() -> None:
    if torch.cuda.is_available():
        torch.cuda.synchronize()


def benchmark_step_fn(
    step_fn: Callable[[torch.Tensor, torch.Tensor], torch.Tensor],
    label: str,
    states_tensor: torch.Tensor,
    actions_tensor: torch.Tensor,
    *,
    iters: int = 200,
) -> Dict[str, float]:
    """Time repeated calls to `step_fn` under identical inputs."""

    torch.manual_seed(0)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(0)

    warmup_iters = max(5, iters // 10)
    for _ in range(warmup_iters):
        step_fn(states_tensor, actions_tensor)
    _sync_if_needed()

    timer = benchmark.Timer(
        stmt="fn(states_tensor, actions_tensor)",
        globals={
            "fn": step_fn,
            "states_tensor": states_tensor,
            "actions_tensor": actions_tensor,
        },
        label=label,
        sub_label=f"device={states_tensor.device}",
        description="step_once microbenchmark",
    )
    result = timer.timeit(iters)
    std_ms = statistics.pstdev(result.raw_times) * 1000 if result.raw_times else float("nan")
    run_count = len(result.raw_times) if result.raw_times else iters
    return {
        "label": label,
        "mean_ms": result.mean * 1000,
        "std_ms": std_ms,
        "iters": run_count,
    }

# %%
benchmark_iters = 20000
results = []

results.append(
    benchmark_step_fn(
        step_once,
        label="Eager step_once",
        states_tensor=states.tensor,
        actions_tensor=actions.tensor,
        iters=benchmark_iters,
    )
)

with warnings.catch_warnings(record=True) as caught:
    warnings.simplefilter("always")
    results.append(
        benchmark_step_fn(
            compiled_step,
            label="torch.compile(step_once)",
            states_tensor=states.tensor,
            actions_tensor=actions.tensor,
            iters=benchmark_iters,
        )
    )
    compile_warning_messages = sorted({str(w.message) for w in caught})

results
# Out:
# [{'label': 'Eager step_once',
#   'mean_ms': 0.10937216250458733,
#   'std_ms': 0.0,
#   'iters': 1},
#  {'label': 'torch.compile(step_once)',
#   'mean_ms': 0.3456614166498184,
#   'std_ms': 0.0,
#   'iters': 1}]

# %%
import torch._dynamo as dynamo


def _format_results(rows):
    header = f"{'Mode':<30} {'mean (ms)':>12} {'std (ms)':>12} {'iters':>8}"
    lines = [header, "-" * len(header)]
    for row in rows:
        lines.append(
            f"{row['label']:<30} {row['mean_ms']:>12.4f} {row['std_ms']:>12.4f} {row['iters']:>8d}"
        )
    return "\n".join(lines)


def _extract_count(report: str, prefix: str) -> int:
    for line in report.splitlines():
        if line.startswith(prefix):
            return int(line.split(":", 1)[1].strip())
    return -1


print(_format_results(results))

eager_mean = next(r for r in results if r["label"] == "Eager step_once")["mean_ms"]
compiled_mean = next(r for r in results if "torch.compile" in r["label"])["mean_ms"]
speedup = eager_mean / compiled_mean if compiled_mean else float("nan")
print(f"\nSpeedup (eager / compiled): {speedup:.3f}x")

compiled_report = dynamo.explain(step_once)(states.tensor, actions.tensor)
compiled_report_text = str(compiled_report)

graph_count = _extract_count(compiled_report_text, "Graph Count")
graph_breaks = _extract_count(compiled_report_text, "Graph Break Count")
break_reasons = sorted(
    {
        line.strip().split(":", 1)[1].strip()
        for line in compiled_report_text.splitlines()
        if line.strip().startswith("Reason:")
    }
)

print(
    f"\nDynamo summary -> Graphs: {graph_count}, Graph breaks: {graph_breaks}, "
    f"Break reasons: {break_reasons or ['None']}"
)

if compile_warning_messages:
    print("\nWarnings during compiled execution:")
    for msg in compile_warning_messages:
        print(f"  - {msg}")
else:
    print("\nWarnings during compiled execution: none captured")
# Out:
# Mode                              mean (ms)     std (ms)    iters
# -----------------------------------------------------------------
# Eager step_once                      0.1094       0.0000        1
# torch.compile(step_once)             0.3457       0.0000        1
#
# Speedup (eager / compiled): 0.316x
#
# Dynamo summary -> Graphs: 12, Graph breaks: 11, Break reasons: ['Dynamic shape operator', 'Unsupported Tensor.item() call with capture_scalar_outputs=False']
#
# Warnings during compiled execution: none captured

# %% [markdown]
# ## Full GFlowNet benchmark
#
# The cell below reuses `train_hypergrid_optimized.py`'s benchmarking entry-point so we can time a larger training loop (Baseline vs compiled) directly from this notebook.

# %%
import importlib
import json
import sys
from pathlib import Path

# Add project root to path (notebook is in tutorials/notebooks/)
project_root = Path.cwd().parent.parent
sys.path.append(str(project_root))
from tutorials.examples import train_hypergrid_optimized as hypergrid_train


# Reload to pick up local edits without restarting the kernel.
importlib.reload(hypergrid_train)


def notebook_benchmark_run(
    *,
    compile_mode: str = "none",
    use_compile: bool = False,
    chunk_size: int = 0,
    n_iterations: int = 200,
    warmup_iters: int = 50,
    seed: int = 0,
    device: str = "cpu",
    label: str,
) -> dict:
    argv_backup = sys.argv
    try:
        sys.argv = [sys.argv[0]]
        args = hypergrid_train.parse_args()
    finally:
        sys.argv = argv_backup
    args.compile = use_compile
    args.compile_mode = compile_mode
    args.chunk_size = chunk_size
    args.n_iterations = n_iterations
    args.warmup_iters = warmup_iters
    args.seed = seed
    args.device = device
    args.benchmark = True
    args.use_vmap = False
    args.loss = "TB"
    args.batch_size = 16
    args.height = 32
    args.ndim = 2

    result = hypergrid_train.train_with_options(
        args,
        device=hypergrid_train.resolve_device(device),
        enable_compile=use_compile,
        use_vmap=False,
        warmup_iters=warmup_iters,
        quiet=True,
        timing=True,
        record_history=True,
        use_chunk=(chunk_size > 0),
    )
    result["label"] = label
    result["compile_mode"] = compile_mode if use_compile else "none"
    return result


scenarios = [
    dict(label="Eager", use_compile=False),
    dict(label="Compiled", use_compile=True, compile_mode="reduce-overhead"),
]

benchmark_runs = []
for scenario in scenarios:
    run_result = notebook_benchmark_run(**scenario)
    benchmark_runs.append(run_result)

benchmark_runs
# Out:
# calculated tensor of all states in 0.0009723345438639323 minutes
# + Environment has 1024 states
# + Environment log partition is 5.711750507354736
# /Users/jdv/code/torchgfn/src/gfn/env.py:495: UserWarning: You're using advanced parameters: (sf). These are only needed for custom action handling. For basic environments, you can omit these.
#   warnings.warn(
# calculated tensor of all states in 0.0007189313570658366 minutes
# + Environment has 1024 states
# + Environment log partition is 5.711750507354736
# [{'elapsed': 6.105575958034024,
#   'losses': [7.572955131530762,
#    2.491760015487671,
#    3.2979516983032227,
#    3.0194754600524902,
#    0.9618801474571228,
#    0.8673862218856812,
#    1.6195870637893677,
#    0.5269477367401123,
#    1.0297844409942627,
#    1.332466959953308,
#    0.6973802447319031,
#    1.6610175371170044,
#    0.47196799516677856,
#    1.980200171470642,
#    2.484879970550537,
#    1.153307557106018,
#    0.5622124671936035,
#    0.7249877452850342,
#    1.2468236684799194,
#    1.9157636165618896,
#    1.5802578926086426,
#    0.9950146675109863,
#    0.9827088713645935,
#    0.9594094753265381,
#    2.0273141860961914,
#    1.0678741931915283,
#    1.7654989957809448,
#    1.8363938331604004,
#    0.5704580545425415,
#    2.0948450565338135,
#    0.8548241853713989,
#    4.518639087677002,
#    1.0827535390853882,
#    1.2317500114440918,
#    0.6395683288574219,
#    1.3933279514312744,
#    1.7131190299987793,
#    1.1856663227081299,
#    1.428055763244629,
#    0.8084158897399902,
#    0.37907153367996216,
#    1.583935260772705,
#    2.161365270614624,
#    1.4849199056625366,
#    1.6980212926864624,
#    0.4082474708557129,
#    1.0781633853912354,
#    0.6617383360862732,
#    0.8540241718292236,
#    0.7804931998252869,
#    1.5323201417922974,
#    1.175217628479004,
#    0.4573594331741333,
#    1.7341632843017578,
#    1.3420581817626953,
#    0.6467706561088562,
#    0.7274094223976135,
#    0.4892826974391937,
#    0.4271280765533447,
#    1.8384681940078735,
#    0.7235350608825684,
#    1.1163365840911865,
#    1.350170612335205,
#    0.42495375871658325,
#    1.4814311265945435,
#    0.9633447527885437,
#    0.7441744804382324,
#    0.49172350764274597,
#    0.8439239859580994,
#    1.7822604179382324,
#    2.700016975402832,
#    1.2268513441085815,
#    1.689005732536316,
#    0.8238610029220581,
#    1.1699678897857666,
#    0.5300710201263428,
#    0.3418184518814087,
#    0.6137208342552185,
#    0.7867594957351685,
#    2.185892343521118,
#    0.521285355091095,
#    1.2726870775222778,
#    0.450527161359787,
#    1.4032469987869263,
#    0.4590965509414673,
#    0.4651802182197571,
#    0.8082336187362671,
#    0.7147279977798462,
#    0.5436726212501526,
#    1.4215888977050781,
#    1.2204718589782715,
#    0.25053414702415466,
#    1.3869221210479736,
#    1.0469372272491455,
#    1.4329015016555786,
#    0.6535708904266357,
#    1.5620619058609009,
#    2.5244903564453125,
#    0.7888399362564087,
#    5.477772235870361,
#    2.438631057739258,
#    1.3707287311553955,
#    0.9398314952850342,
#    0.46227526664733887,
#    0.5834711790084839,
#    1.6012723445892334,
#    1.7451685667037964,
#    0.9019611477851868,
#    0.7608010172843933,
#    1.2909115552902222,
#    0.4646669626235962,
#    0.4738759398460388,
#    0.7258164882659912,
#    1.7222124338150024,
#    2.4299848079681396,
#    2.2367324829101562,
#    2.0737838745117188,
#    0.5498713254928589,
#    1.791583776473999,
#    1.1461840867996216,
#    0.2634006142616272,
#    0.8089989423751831,
#    0.283713698387146,
#    0.14579910039901733,
#    0.8403635621070862,
#    0.5281050205230713,
#    0.3584972620010376,
#    0.6050671935081482,
#    0.4479628801345825,
#    0.5756915211677551,
#    1.256803035736084,
#    0.7478235960006714,
#    0.375349760055542,
#    0.35438239574432373,
#    1.180328369140625,
#    1.3136284351348877,
#    3.27740478515625,
#    1.0790156126022339,
#    1.540788173675537,
#    1.0326931476593018,
#    0.9449985027313232,
#    3.155139684677124,
#    0.9995787143707275,
#    0.7784771919250488,
#    1.443956732749939,
#    0.8618024587631226,
#    0.3689582049846649,
#    0.4708964228630066,
#    1.133431315422058,
#    1.1145482063293457,
#    0.4921965003013611,
#    0.415180504322052,
#    1.5828590393066406,
#    2.7756614685058594,
#    0.6000064611434937,
#    0.7194350957870483,
#    0.8013563752174377,
#    1.2213236093521118,
#    1.1368153095245361,
#    1.3761565685272217,
#    0.346245139837265,
#    0.3820178508758545,
#    0.4246070384979248,
#    0.5360602140426636,
#    0.6117574572563171,
#    1.0365396738052368,
#    0.191411092877388,
#    0.6832408905029297,
#    1.0592424869537354,
#    0.6425431966781616,
#    0.498931348323822,
#    0.774171769618988,
#    0.32929566502571106,
#    0.42261868715286255,
#    0.3470837473869324,
#    0.4950379729270935,
#    0.5027860403060913,
#    0.35800668597221375,
#    1.288243293762207,
#    0.6900274753570557,
#    1.4558058977127075,
#    1.1142147779464722,
#    0.2911098003387451,
#    0.7661944031715393,
#    1.0826146602630615,
#    1.19940984249115,
#    0.884093701839447,
#    0.5238901972770691,
#    0.6807741522789001,
#    0.5270069241523743,
#    0.43598586320877075,
#    0.31679433584213257,
#    0.7662327885627747,
#    0.4052656292915344,
#    0.4683819115161896,
#    0.4934506416320801,
#    0.17495952546596527,
#    0.5440036654472351,
#    0.5274096131324768,
#    0.6581551432609558],
#   'iter_times': [0.029843291034922004,
#    0.02665925002656877,
#    0.026591749861836433,
#    0.02578529203310609,
#    0.0249330410733819,
#    0.02374075003899634,
#    0.02827424998395145,
#    0.016017750138416886,
#    0.025069749914109707,
#    0.02290912508033216,
#    0.01798625010997057,
#    0.022280167089775205,
#    0.021828250028192997,
#    0.025819166796281934,
#    0.023717750096693635,
#    0.027398916892707348,
#    0.0268092080950737,
#    0.02269370900467038,
#    0.028668625047430396,
#    0.025364749832078815,
#    0.026112499879673123,
#    0.03050654218532145,
#    0.026381792034953833,
#    0.02492345799691975,
#    0.024277166929095984,
#    0.025802375050261617,
#    0.023120166966691613,
#    0.022838874952867627,
#    0.02152595785446465,
#    0.02243420807644725,
#    0.026837416924536228,
#    0.02476345794275403,
#    0.027901625027880073,
#    0.02595195802859962,
#    0.029563874937593937,
#    0.02456283406354487,
#    0.023599833017215133,
#    0.027492624940350652,
#    0.022965540876612067,
#    0.02508420799858868,
#    0.028139542089775205,
#    0.025828625075519085,
#    0.028102665906772017,
#    0.026154458988457918,
#    0.027773250127211213,
#    0.025903834030032158,
#    0.028939666924998164,
#    0.024504374945536256,
#    0.02638370799832046,
#    0.025218249997124076,
#    0.023709542118012905,
#    0.03099012514576316,
#    0.021817500004544854,
#    0.025243084179237485,
#    0.031247250037267804,
#    0.026461832923814654,
#    0.02370858401991427,
#    0.02921529207378626,
#    0.02194329211488366,
#    0.02969479188323021,
#    0.02624008315615356,
#    0.025315249804407358,
#    0.030012167058885098,
#    0.032295542070642114,
#    0.029138999991118908,
#    0.02831891691312194,
#    0.02835141704417765,
#    0.02719200006686151,
#    0.027825874974951148,
#    0.024933042004704475,
#    0.03004787489771843,
#    0.0257573330309242,
#    0.02414166694507003,
#    0.028785540955141187,
#    0.029787667095661163,
#    0.03012562496587634,
#    0.0186317500192672,
#    0.026522708125412464,
#    0.025528999976813793,
#    0.02337670815177262,
#    0.028197707841172814,
#    0.028563749976456165,
#    0.023193708853796124,
#    0.023533583153039217,
#    0.023977917153388262,
#    0.025529957842081785,
#    0.025657958118245006,
#    0.028129874961450696,
#    0.0250042078550905,
#    0.024240750120952725,
#    0.02651733416132629,
#    0.03236395795829594,
#    0.03119733394123614,
#    0.023247458040714264,
#    0.02916412497870624,
#    0.03493220801465213,
#    0.026215665973722935,
#    0.0358433339279145,
#    0.03177366708405316,
#    0.03824399993754923,
#    0.03338041715323925,
#    0.034712209133431315,
#    0.03465991700068116,
#    0.02921774983406067,
#    0.02734670788049698,
#    0.032816499937325716,
#    0.02972904103808105,
#    0.032379542011767626,
#    0.03371258289553225,
#    0.03127762512303889,
#    0.02719833399169147,
#    0.025000832974910736,
#    0.03524758294224739,
#    0.03120354190468788,
#    0.03501374996267259,
#    0.03635912504978478,
#    0.0354501660913229,
#    0.03287862497381866,
#    0.029975875047966838,
#    0.03692404204048216,
#    0.02574570896103978,
#    0.03072458296082914,
#    0.03142145904712379,
#    0.034465207951143384,
#    0.032932084053754807,
#    0.03766591614112258,
#    0.031669416930526495,
#    0.03097916697151959,
#    0.024389415979385376,
#    0.026578041957691312,
#    0.028716041008010507,
#    0.032391542103141546,
#    0.03359537501819432,
#    0.029333041980862617,
#    0.03852045815438032,
#    0.03522874996997416,
#    0.039978290908038616,
#    0.03800995904020965,
#    0.03813070897012949,
#    0.03231212496757507,
#    0.039890124928206205,
#    0.03974391706287861,
#    0.040384375024586916,
#    0.03584462497383356,
#    0.03564045880921185,
#    0.03651641705073416,
#    0.037402458023279905,
#    0.03648191690444946,
#    0.03885470796376467,
#    0.03411237499676645,
#    0.03694487502798438,
#    0.02758374996483326,
#    0.03918912494555116,
#    0.03915116610005498,
#    0.03766429191455245,
#    0.034370541106909513,
#    0.03439179202541709,
#    0.03841937496326864,
#    0.039793833857402205,
#    0.03862112481147051,
#    0.03574187494814396,
#    0.03246379108168185,
#    0.036486207973212004,
#    0.03896020818501711,
#    0.03466787491925061,
#    0.0354886669665575,
#    0.03665566607378423,
#    0.03877758304588497,
#    0.03936316608451307,
#    0.04036858305335045,
#    0.03711925004608929,
#    0.03579937503673136,
#    0.0394124158192426,
#    0.03487608302384615,
#    0.033077584113925695,
#    0.03582812496460974,
#    0.03510708408430219,
#    0.03271691710688174,
#    0.024238749872893095,
#    0.0317631671205163,
#    0.037570209009572864,
#    0.037720915861427784,
#    0.03836658294312656,
#    0.03753329208120704,
#    0.03856374998576939,
#    0.03874720796011388,
#    0.038331500021740794,
#    0.03494950011372566,
#    0.03934533311985433,
#    0.034773917170241475,
#    0.0353236251976341,
#    0.03172524995170534,
#    0.03164450009353459,
#    0.02425049990415573,
#    0.03322154190391302,
#    0.036195874912664294,
#    0.03410979197360575,
#    0.03734816703945398,
#    0.039303625002503395,
#    0.03886774997226894],
#   'compile_mode': 'none',
#   'use_compile': False,
#   'requested_vmap': False,
#   'effective_vmap': False,
#   'chunk_size_effective': 0,
#   'label': 'Eager'},
#  {'elapsed': 6.3454663751181215,
#   'losses': [7.57296085357666,
#    2.4917588233947754,
#    3.297954797744751,
#    3.0194761753082275,
#    0.9618798494338989,
#    0.8673862218856812,
#    1.61958646774292,
#    0.5269474983215332,
#    1.0297842025756836,
#    1.332466721534729,
#    0.6973803639411926,
#    1.6610198020935059,
#    0.471968412399292,
#    1.9802007675170898,
#    2.4848790168762207,
#    1.1533082723617554,
#    0.5622122883796692,
#    0.7249880433082581,
#    1.2468247413635254,
#    1.9157638549804688,
#    1.580257773399353,
#    0.9950148463249207,
#    0.9827099442481995,
#    0.9594108462333679,
#    2.0273146629333496,
#    1.0678751468658447,
#    1.7654999494552612,
#    1.8363943099975586,
#    0.5704579949378967,
#    2.0948455333709717,
#    0.8548235893249512,
#    4.518638610839844,
#    1.0827548503875732,
#    1.2317492961883545,
#    0.6395676732063293,
#    1.3933277130126953,
#    1.7131195068359375,
#    1.1856666803359985,
#    1.4280558824539185,
#    0.8084155917167664,
#    0.3790717124938965,
#    1.5839354991912842,
#    2.1613659858703613,
#    1.4849202632904053,
#    1.6980226039886475,
#    0.4082470238208771,
#    1.0781641006469727,
#    0.6617385149002075,
#    0.8540250062942505,
#    0.7804922461509705,
#    1.532320499420166,
#    1.1752188205718994,
#    0.45735907554626465,
#    1.7341620922088623,
#    1.3420584201812744,
#    0.6467709541320801,
#    0.7274090647697449,
#    0.4892843961715698,
#    0.42712870240211487,
#    1.8384690284729004,
#    0.7235339879989624,
#    1.1163374185562134,
#    1.3501720428466797,
#    0.42495307326316833,
#    1.4814316034317017,
#    0.9633446335792542,
#    0.7441746592521667,
#    0.49172279238700867,
#    0.8439255952835083,
#    1.7822625637054443,
#    2.70001482963562,
#    1.226853370666504,
#    1.6889946460723877,
#    0.8238599300384521,
#    1.1699568033218384,
#    0.5300586223602295,
#    0.34182092547416687,
#    0.6136969327926636,
#    0.7866867780685425,
#    2.1859169006347656,
#    0.5212369561195374,
#    1.2727247476577759,
#    0.45056644082069397,
#    1.4032206535339355,
#    0.4590488374233246,
#    0.4650927782058716,
#    0.8082565665245056,
#    0.7144088745117188,
#    0.543725311756134,
#    1.4212666749954224,
#    1.2204252481460571,
#    0.25085633993148804,
#    1.3868451118469238,
#    1.0468615293502808,
#    1.4329462051391602,
#    0.6538652777671814,
#    1.561804175376892,
#    2.5266776084899902,
#    0.7883028984069824,
#    5.479814529418945,
#    2.439664840698242,
#    1.371835470199585,
#    0.9409430027008057,
#    0.46193727850914,
#    0.5832473039627075,
#    1.6056299209594727,
#    1.7503899335861206,
#    0.9054805040359497,
#    0.7594331502914429,
#    1.2933785915374756,
#    0.4637310206890106,
#    0.47456109523773193,
#    0.7240238189697266,
#    1.725350260734558,
#    2.4346182346343994,
#    2.2380924224853516,
#    2.0717313289642334,
#    0.5502132177352905,
#    1.7969448566436768,
#    1.1502264738082886,
#    0.26300373673439026,
#    0.8080339431762695,
#    0.28202709555625916,
#    0.145426943898201,
#    0.8435786962509155,
#    0.5270522236824036,
#    0.3560110628604889,
#    0.609140157699585,
#    0.4524146318435669,
#    0.5814225077629089,
#    1.2689967155456543,
#    0.5928022861480713,
#    0.2952418625354767,
#    0.24432311952114105,
#    0.7377331256866455,
#    0.8195648193359375,
#    1.2766600847244263,
#    0.9409489035606384,
#    0.830878496170044,
#    0.4374370574951172,
#    0.3859502971172333,
#    2.2971324920654297,
#    0.41110262274742126,
#    0.7398536801338196,
#    0.43272972106933594,
#    0.5752124190330505,
#    0.3000510632991791,
#    0.8548444509506226,
#    0.373995304107666,
#    1.8866313695907593,
#    1.077983021736145,
#    0.5132556557655334,
#    1.1473032236099243,
#    0.6178485155105591,
#    0.4333594739437103,
#    1.4737694263458252,
#    0.9747253060340881,
#    1.5080058574676514,
#    1.314931869506836,
#    0.9588497877120972,
#    0.39719900488853455,
#    1.0430501699447632,
#    1.1309837102890015,
#    0.43614932894706726,
#    0.58064204454422,
#    1.1400829553604126,
#    0.3988802433013916,
#    0.963148832321167,
#    2.17482328414917,
#    1.3901969194412231,
#    0.3156747817993164,
#    0.5436887741088867,
#    0.36854708194732666,
#    0.37455135583877563,
#    0.2726321220397949,
#    0.3139721155166626,
#    0.5012255311012268,
#    0.820480227470398,
#    1.0951125621795654,
#    0.6761919856071472,
#    0.790934145450592,
#    0.9907330274581909,
#    0.8022286891937256,
#    0.3866922855377197,
#    0.7084116339683533,
#    0.866324245929718,
#    0.46766072511672974,
#    0.26419714093208313,
#    0.32584092020988464,
#    1.2846601009368896,
#    0.39885473251342773,
#    1.0205860137939453,
#    0.27573293447494507,
#    0.24224549531936646,
#    0.6909810900688171,
#    0.3044925034046173,
#    0.25011563301086426,
#    0.44614750146865845,
#    0.6451624035835266,
#    0.5779326558113098],
#   'iter_times': [0.03169812494888902,
#    0.027584708062931895,
#    0.02858670800924301,
#    0.026709083002060652,
#    0.0258675420191139,
#    0.02468925016000867,
#    0.030730166006833315,
#    0.016805625054985285,
#    0.026752999983727932,
#    0.023861791007220745,
#    0.01803375012241304,
#    0.022661666851490736,
#    0.02204920817166567,
#    0.02710441709496081,
#    0.02583591709844768,
#    0.027296457905322313,
#    0.027498583076521754,
#    0.023009249940514565,
#    0.029670832911506295,
#    0.026142749935388565,
#    0.026309833861887455,
#    0.032059666933491826,
#    0.02789283310994506,
#    0.02576716709882021,
#    0.02486624987795949,
#    0.027173375012353063,
#    0.02338912500999868,
#    0.024146082811057568,
#    0.02213795785792172,
#    0.023384332889690995,
#    0.02873941697180271,
#    0.0250537081155926,
#    0.028922915924340487,
#    0.02695966698229313,
#    0.03005241695791483,
#    0.025074792094528675,
#    0.02407074999064207,
#    0.028803542023524642,
#    0.024359500035643578,
#    0.025547208031639457,
#    0.02867558295838535,
#    0.02669191686436534,
#    0.02979383314959705,
#    0.026735665975138545,
#    0.028341416968032718,
#    0.026234874967485666,
#    0.030128249898552895,
#    0.02529741614125669,
#    0.027294500032439828,
#    0.026511665899306536,
#    0.024816541001200676,
#    0.03207574994303286,
#    0.02337020798586309,
#    0.026867209002375603,
#    0.03262049984186888,
#    0.026773500023409724,
#    0.025173667119815946,
#    0.030965832993388176,
#    0.023638332961127162,
#    0.03076474997214973,
#    0.026863333070650697,
#    0.025366832967847586,
#    0.03145316708832979,
#    0.03426345810294151,
#    0.03046545898541808,
#    0.029700499959290028,
#    0.029783915961161256,
#    0.02838366595096886,
#    0.029486834071576595,
#    0.02670641685836017,
#    0.031350333942100406,
#    0.027266208082437515,
#    0.025731500005349517,
#    0.030091083142906427,
#    0.031152040930464864,
#    0.03152075014077127,
#    0.01954770809970796,
#    0.026827292051166296,
#    0.027664915891364217,
#    0.024289875058457255,
#    0.02911649993620813,
#    0.029995207907631993,
#    0.02480362495407462,
#    0.024720708839595318,
#    0.024827249813824892,
#    0.027033083140850067,
#    0.027515250025317073,
#    0.029572209110483527,
#    0.02584737492725253,
#    0.02511425013653934,
#    0.02771108318120241,
#    0.03237133310176432,
#    0.032289124792441726,
#    0.024745125090703368,
#    0.03070554183796048,
#    0.0387380828615278,
#    0.027526458026841283,
#    0.038875750033184886,
#    0.033374999882653356,
#    0.04179483302868903,
#    0.03558491705916822,
#    0.03673141589388251,
#    0.03694891603663564,
#    0.031565249897539616,
#    0.029297207947820425,
#    0.03449812508188188,
#    0.032412667060270905,
#    0.03472112491726875,
#    0.03546695807017386,
#    0.03327808412723243,
#    0.028670792002230883,
#    0.02604879206046462,
#    0.037921792129054666,
#    0.03335845796391368,
#    0.03821487491950393,
#    0.038532041013240814,
#    0.038210750091820955,
#    0.034492208855226636,
#    0.03084229095838964,
#    0.03950933297164738,
#    0.026532666059210896,
#    0.03208570904098451,
#    0.03370637493208051,
#    0.03659145790152252,
#    0.03467929200269282,
#    0.03974362509325147,
#    0.03336887480691075,
#    0.03240949986502528,
#    0.025664541870355606,
#    0.02777195884846151,
#    0.030273291980847716,
#    0.039200125029310584,
#    0.02961912495084107,
#    0.030783750116825104,
#    0.03524379199370742,
#    0.039315874921157956,
#    0.04285550001077354,
#    0.03660220908932388,
#    0.04133837507106364,
#    0.03899241704493761,
#    0.03553324984386563,
#    0.03786025010049343,
#    0.032377874944359064,
#    0.028963749995455146,
#    0.03383512492291629,
#    0.028710374841466546,
#    0.03110875003039837,
#    0.030619458062574267,
#    0.03356295800767839,
#    0.03945783409290016,
#    0.039811542024835944,
#    0.03152520814910531,
#    0.040032291086390615,
#    0.038056124933063984,
#    0.03658033302053809,
#    0.03990195784717798,
#    0.038062167121097445,
#    0.041290540946647525,
#    0.040220499970018864,
#    0.036755625158548355,
#    0.03777787508442998,
#    0.04015366593375802,
#    0.0368197918869555,
#    0.038513916078954935,
#    0.03783300006762147,
#    0.04108829190954566,
#    0.038560917135328054,
#    0.04114095913246274,
#    0.04210358299314976,
#    0.04152379208244383,
#    0.03358387481421232,
#    0.03409449988976121,
#    0.03836424998007715,
#    0.03440766618587077,
#    0.0377882921602577,
#    0.03659795899875462,
#    0.037964458810165524,
#    0.03920579212717712,
#    0.04200679203495383,
#    0.03882258292287588,
#    0.039652334060519934,
#    0.037086208118125796,
#    0.04016891587525606,
#    0.04108100011944771,
#    0.038782832911238074,
#    0.037558333948254585,
#    0.04046133300289512,
#    0.03616187488660216,
#    0.03772379201836884,
#    0.040625750087201595,
#    0.0360937500372529,
#    0.039527124958112836,
#    0.02647212496958673,
#    0.03991162497550249,
#    0.034061457961797714,
#    0.03235474997200072,
#    0.025128833018243313,
#    0.03827429190278053,
#    0.03287583403289318,
#    0.03880300000309944],
#   'compile_mode': 'reduce-overhead',
#   'use_compile': True,
#   'requested_vmap': False,
#   'effective_vmap': False,
#   'chunk_size_effective': 0,
#   'label': 'Compiled'}]

# %%
import pandas as pd

benchmark_df = pd.DataFrame(benchmark_runs)
display(
    benchmark_df[
        [
            "label",
            "elapsed",
            "compile_mode",
            "effective_vmap",
            "chunk_size_effective",
        ]
    ]
)

baseline = benchmark_df.iloc[0]
print("Baseline label:", baseline["label"], "elapsed:", f"{baseline['elapsed']:.2f}s")
for idx in range(1, len(benchmark_df)):
    row = benchmark_df.iloc[idx]
    speedup = baseline["elapsed"] / row["elapsed"] if row["elapsed"] else float("inf")
    print(
        f"{row['label']} elapsed={row['elapsed']:.2f}s "
        f"({speedup:.2f}x vs baseline), compile_mode={row['compile_mode']}"
    )
# Out:
#       label   elapsed     compile_mode  effective_vmap  chunk_size_effective
# 0     Eager  6.105576             none           False                     0
# 1  Compiled  6.345466  reduce-overhead           False                     0
# Baseline label: Eager elapsed: 6.11s
# Compiled elapsed=6.35s (0.96x vs baseline), compile_mode=reduce-overhead

# %% [markdown]
# ## Dynamo trace analysis
#
# `torch._dynamo.explain` gives a per-graph summary: captured ops, guards, and where graph breaks (if any) occur. The cell below reuses the state/action tensors above and prints the explanation so you can confirm there is only one graph and zero breaks.

# %%
import torch._dynamo as dynamo

explanation = dynamo.explain(step_once)(states.tensor, actions.tensor)
print(explanation)
# Out:
# Graph Count: 16
# Graph Break Count: 15
# Op Count: 24
# Break Reasons:
#   Break Reason 1:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /var/folders/hd/jqxc7ns56l35q_zyk7xmptmw0000gn/T/ipykernel_75536/351529152.py, line 18 in step_once>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/env.py, line 680 in _step>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/env.py, line 306 in _step>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/actions.py, line 149 in __getitem__>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/actions.py, line 188 in _mask_select>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 2:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/env.py, line 306 in _step>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/actions.py, line 149 in __getitem__>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/actions.py, line 188 in _mask_select>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 3:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 4:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/states.py, line 292 in _mask_select>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 5:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 6:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/states.py, line 589 in __getitem__>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 7:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 8:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/states.py, line 596 in __getitem__>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 9:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/env.py, line 340 in _step>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/states.py, line 587 in __getitem__>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/states.py, line 292 in _mask_select>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
#   Break Reason 10:
#     Reason: Dynamic shape operator
#   Explanation: Operator `aten.repeat_interleave.Tensor`'s output shape depends on input Tensor data.
#   Hint: Enable tracing of dynamic shape operators with `torch._dynamo.config.capture_dynamic_output_shape_ops = True`
#
#   Developer debug context: aten.repeat_interleave.Tensor
#
#     User Stack:
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/env.py, line 341 in _step>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/actions.py, line 149 in __getitem__>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/actions.py, line 188 in _mask_select>
#       <FrameSummary file /Users/jdv/code/torchgfn/src/gfn/utils/mask_select.py, line 66 in boolean_mask_select>
# Ops per Graph:
#   Ops 1:
#     <built-in method ones of type object at 0x1238bca40>
#     <built-in method ones of type object at 0x1238bca40>
#   Ops 2:
#     <built-in function invert>
#   Ops 3:
#     <built-in method arange of type object at 0x1238bca40>
#   Ops 4:
#     <built-in method index_select of type object at 0x1238bca40>
#   Ops 5:
#   Ops 6:
#     <built-in method arange of type object at 0x1238bca40>
#   Ops 7:
#     <built-in method index_select of type object at 0x1238bca40>
#   Ops 8:
#   Ops 9:
#     <built-in method arange of type object at 0x1238bca40>
#   Ops 10:
#     <built-in method index_select of type object at 0x1238bca40>
#   Ops 11:
#   Ops 12:
#   Ops 13:
#     <built-in method gather of type object at 0x1238bca40>
#     aten._assert_async.msg
#     <built-in function invert>
#     <built-in function and_>
#   Ops 14:
#   Ops 15:
#     <built-in method ones of type object at 0x1238bca40>
#     <built-in method ones of type object at 0x1238bca40>
#     <built-in method ones of type object at 0x1238bca40>
#     <built-in method ones of type object at 0x1238bca40>
#     <built-in function setitem>
#     <built-in function setitem>
#     <built-in function setitem>
#   Ops 16:
#     <built-in function setitem>
#     <built-in method zeros of type object at 0x1238bca40>
#     <built-in method cat of type object at 0x1238bca40>
#     <built-in function setitem>
# Out Guards:
#   Guard 1:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 2:
#     Name: "G['__import_gfn_dot_states'].torch"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'].torch, 4351320976)"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 3:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: ['SHAPE_ENV']
#     Code List: ["2 <= L['states_tensor'].size()[0]"]
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 4:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 5:
#     Name: "G['__import_gfn_dot_states']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'], 5499072048)"]
#     Object Weakref: <weakref at 0x31eb49b70; to 'module' at 0x147c52e30>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 6:
#     Name: "L['states_tensor']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['states_tensor'], 5106997584)"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 7:
#     Name: "G['env'].States.s0"
#     Source: global
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(G['env'].States.s0, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31d844ef0; to 'Tensor' at 0x12282a7a0>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 8:
#     Name: "G['env']"
#     Source: global
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(G['env'], 6146079840)"]
#     Object Weakref: <weakref at 0x31eb4bab0; to 'HyperGrid' at 0x104aeb250>
#     Guarded Class Weakref: <weakref at 0x3048a2570; to 'ABCMeta' at 0x16e55bc60 (HyperGrid)>
#   Guard 9:
#     Name: "L['actions_tensor']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['actions_tensor'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a520; to 'Tensor' at 0x3048d9a80>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 10:
#     Name: "G['__builtins_dict___66']['zip']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___66']['zip'], 4305487296)"]
#     Object Weakref: <weakref at 0x100b7c860; to 'type' at 0x100a085c0>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 11:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 12:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 13:
#     Name: "G['__builtins_dict___66']['isinstance']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___66']['isinstance'], 4307013760)"]
#     Object Weakref: <weakref at 0x31eb406d0; to 'builtin_function_or_method' at 0x100b7d080>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 14:
#     Name: "G['__builtins_dict___66']['tuple']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___66']['tuple'], 4305555088)"]
#     Object Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 15:
#     Name: "G['__builtins_dict___66']['len']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___66']['len'], 4307014080)"]
#     Object Weakref: <weakref at 0x31eb4a9d0; to 'builtin_function_or_method' at 0x100b7d1c0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 16:
#     Name: "G['__import_gfn_dot_states'].torch.bool"
#     Source: global
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['__import_gfn_dot_states'].torch.bool == torch.bool"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef290; to 'type' at 0x1238b8de0 (dtype)>
#   Guard 17:
#     Name: "L['states_tensor']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['states_tensor'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 18:
#     Name: "G['env'].States.sf"
#     Source: global
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(G['env'].States.sf, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31e973c90; to 'Tensor' at 0x147a2cbd0>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 19:
#     Name: "G['__builtins_dict___66']['super']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___66']['super'], 4305490664)"]
#     Object Weakref: <weakref at 0x100b42d40; to 'type' at 0x100a092e8>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 20:
#     Name: "G['env'].States.n_actions"
#     Source: global
#     Create Function: EQUALS_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['env'].States.n_actions == 3"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 21:
#     Name: "G['__import_gfn_dot_states'].torch.ones"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'].torch.ones, 4428225552)"]
#     Object Weakref: <weakref at 0x31eb40810; to 'builtin_function_or_method' at 0x107f15c10>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 22:
#     Name: "G['env'].Actions.action_shape"
#     Source: global
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(G['env'].Actions.action_shape, 4305555088)", "len(G['env'].Actions.action_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 23:
#     Name: "G['env'].States.state_shape"
#     Source: global
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(G['env'].States.state_shape, 4305555088)", "len(G['env'].States.state_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 24:
#     Name: "G['env'].Actions.action_shape[0]"
#     Source: global
#     Create Function: EQUALS_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['env'].Actions.action_shape[0] == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 25:
#     Name: "G['env'].States.state_shape[0]"
#     Source: global
#     Create Function: EQUALS_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['env'].States.state_shape[0] == 2"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 26:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 27:
#     Name: "L['states_tensor'].to"
#     Source: local
#     Create Function: HASATTR
#     Guard Types: ['HASATTR']
#     Code List: ["hasattr(L['states_tensor'], 'to')"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 28:
#     Name: "G['env'].States"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['env'].States, 6146094768)"]
#     Object Weakref: <weakref at 0x147c837e0; to 'ABCMeta' at 0x16e55f6b0>
#     Guarded Class Weakref: <weakref at 0x100c198f0; to 'type' at 0x14070bef0 (ABCMeta)>
#   Guard 29:
#     Name: "G['env'].Actions"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['env'].Actions, 6146095712)"]
#     Object Weakref: <weakref at 0x3048d99e0; to 'ABCMeta' at 0x16e55fa60>
#     Guarded Class Weakref: <weakref at 0x100c198f0; to 'type' at 0x14070bef0 (ABCMeta)>
#   Guard 30:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 31:
#     Name: "G['__builtins_dict___70']['isinstance']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___70']['isinstance'], 4307013760)"]
#     Object Weakref: <weakref at 0x31eb406d0; to 'builtin_function_or_method' at 0x100b7d080>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 32:
#     Name: "G['__import_gfn_dot_states'].torch"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'].torch, 4351320976)"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 33:
#     Name: "G['__builtins_dict___70']['zip']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___70']['zip'], 4305487296)"]
#     Object Weakref: <weakref at 0x100b7c860; to 'type' at 0x100a085c0>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 34:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 35:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 36:
#     Name: "G['__builtins_dict___70']['len']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___70']['len'], 4307014080)"]
#     Object Weakref: <weakref at 0x31eb4a9d0; to 'builtin_function_or_method' at 0x100b7d1c0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 37:
#     Name: "G['__import_gfn_dot_states']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'], 5499072048)"]
#     Object Weakref: <weakref at 0x31eb49b70; to 'module' at 0x147c52e30>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 38:
#     Name: "G['__builtins_dict___70']['tuple']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___70']['tuple'], 4305555088)"]
#     Object Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 39:
#     Name: "L['actions']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['actions'], 6146095712)"]
#     Object Weakref: <weakref at 0x31eb43740; dead>
#     Guarded Class Weakref: <weakref at 0x3048d99e0; to 'ABCMeta' at 0x16e55fa60 (DiscreteEnvActions)>
#   Guard 40:
#     Name: "G['__import_gfn_dot_states'].torch.Tensor"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'].torch.Tensor, 5106997584)"]
#     Object Weakref: <weakref at 0x1176e1b20; to '_TensorMeta' at 0x130669950>
#     Guarded Class Weakref: <weakref at 0x104bfcd10; to 'type' at 0x1238bcd38 (_TensorMeta)>
#   Guard 41:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 42:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 43:
#     Name: "L['states'].__class__.sf"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['states'].__class__.sf, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31e973c90; to 'Tensor' at 0x147a2cbd0>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 44:
#     Name: "L['actions'].tensor"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['actions'].tensor, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a520; to 'Tensor' at 0x3048d9a80>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 45:
#     Name: "G['torch']"
#     Source: global
#     Create Function: DUPLICATE_INPUT
#     Guard Types: ['DUPLICATE_INPUT']
#     Code List: ["G['__import_gfn_dot_states'].torch is G['torch']"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 46:
#     Name: "L['self']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['self'], 6146079840)"]
#     Object Weakref: <weakref at 0x31eb4bab0; to 'HyperGrid' at 0x104aeb250>
#     Guarded Class Weakref: <weakref at 0x3048a2570; to 'ABCMeta' at 0x16e55bc60 (HyperGrid)>
#   Guard 47:
#     Name: "G['__import_gfn_dot_states'].torch.bool"
#     Source: global
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['__import_gfn_dot_states'].torch.bool == torch.bool"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef290; to 'type' at 0x1238b8de0 (dtype)>
#   Guard 48:
#     Name: "L['states'].tensor"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['states'].tensor, 5106997584)"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 49:
#     Name: "L['states']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['states'], 6146094768)"]
#     Object Weakref: <weakref at 0x30bb6aac0; dead>
#     Guarded Class Weakref: <weakref at 0x147c837e0; to 'ABCMeta' at 0x16e55f6b0 (DiscreteEnvStates)>
#   Guard 50:
#     Name: "L['self'].check_action_validity"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['BOOL_MATCH']
#     Code List: ["L['self'].check_action_validity == True"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af27a0; to 'type' at 0x100a19190 (bool)>
#   Guard 51:
#     Name: "L['states'].state_shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['states'].state_shape, 4305555088)", "len(L['states'].state_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 52:
#     Name: "G['__import_gfn_dot_states'].ensure_same_device"
#     Source: global
#     Create Function: CLOSURE_MATCH
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 53:
#     Name: "L['states'].tensor.shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['states'].tensor.shape, 4891320080)", "len(L['states'].tensor.shape) == 2"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef100; to 'type' at 0x1238b9f10 (Size)>
#   Guard 54:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 55:
#     Name: "L['states'].tensor"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['states'].tensor, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 56:
#     Name: "L['actions'].action_shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['actions'].action_shape, 4305555088)", "len(L['actions'].action_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 57:
#     Name: "L['states'].state_shape[0]"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['states'].state_shape[0] == 2"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 58:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 59:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 60:
#     Name: "G['torch']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'], 4351320976)"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 61:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 62:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 63:
#     Name: "L['self']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['self'], 6146095712)"]
#     Object Weakref: <weakref at 0x31eb43740; dead>
#     Guarded Class Weakref: <weakref at 0x3048d99e0; to 'ABCMeta' at 0x16e55fa60 (DiscreteEnvActions)>
#   Guard 64:
#     Name: "G['__builtins_dict___74']['isinstance']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___74']['isinstance'], 4307013760)"]
#     Object Weakref: <weakref at 0x31eb406d0; to 'builtin_function_or_method' at 0x100b7d080>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 65:
#     Name: "L['index']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['index'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a2a0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 66:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 67:
#     Name: "G['torch'].Tensor"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'].Tensor, 5106997584)"]
#     Object Weakref: <weakref at 0x1176e1b20; to '_TensorMeta' at 0x130669950>
#     Guarded Class Weakref: <weakref at 0x104bfcd10; to 'type' at 0x1238bcd38 (_TensorMeta)>
#   Guard 68:
#     Name: "G['torch'].bool"
#     Source: global
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['torch'].bool == torch.bool"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef290; to 'type' at 0x1238b8de0 (dtype)>
#   Guard 69:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 70:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 71:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 72:
#     Name: "L['self'].action_shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['self'].action_shape, 4305555088)", "len(L['self'].action_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 73:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 74:
#     Name: "G['__builtins_dict___77']['len']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___77']['len'], 4307014080)"]
#     Object Weakref: <weakref at 0x31eb4a9d0; to 'builtin_function_or_method' at 0x100b7d1c0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 75:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 76:
#     Name: "L['self']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['self'], 6146095712)"]
#     Object Weakref: <weakref at 0x31eb43740; dead>
#     Guarded Class Weakref: <weakref at 0x3048d99e0; to 'ABCMeta' at 0x16e55fa60 (DiscreteEnvActions)>
#   Guard 77:
#     Name: "G['__builtins_dict___77']['tuple']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___77']['tuple'], 4305555088)"]
#     Object Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 78:
#     Name: "G['boolean_mask_select']"
#     Source: global
#     Create Function: CLOSURE_MATCH
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 79:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 80:
#     Name: "L['self'].tensor"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['self'].tensor, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a520; to 'Tensor' at 0x3048d9a80>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 81:
#     Name: "L['mask']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['mask'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a2a0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 82:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 83:
#     Name: "L['mask'].to"
#     Source: local
#     Create Function: HASATTR
#     Guard Types: ['HASATTR']
#     Code List: ["hasattr(L['mask'], 'to')"]
#     Object Weakref: <weakref at 0x31eb4a2a0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 84:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 85:
#     Name: "L['mask']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['mask'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a2a0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 86:
#     Name: "G['torch'].arange"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'].arange, 4428197584)"]
#     Object Weakref: <weakref at 0x31eb87380; to 'builtin_function_or_method' at 0x107f0eed0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 87:
#     Name: "G['torch'].repeat_interleave"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'].repeat_interleave, 4428289808)"]
#     Object Weakref: <weakref at 0x31eb87650; to 'builtin_function_or_method' at 0x107f25710>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 88:
#     Name: "G['_expand_mask_to_batch']"
#     Source: global
#     Create Function: CLOSURE_MATCH
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 89:
#     Name: "L['batch_shape'][0]"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['batch_shape'][0] == 4"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 90:
#     Name: "G['__import_torch_dot__dynamo_dot_polyfills'].types.FunctionType"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_torch_dot__dynamo_dot_polyfills'].types.FunctionType, 4305497480)"]
#     Object Weakref: <weakref at 0x100b30360; to 'type' at 0x100a0ad88>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 91:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 92:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 93:
#     Name: "G['__import_torch_dot__dynamo_dot_polyfills'].cmp_eq"
#     Source: global
#     Create Function: CLOSURE_MATCH
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 94:
#     Name: "G['torch'].int64"
#     Source: global
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['torch'].int64 == torch.int64"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef290; to 'type' at 0x1238b8de0 (dtype)>
#   Guard 95:
#     Name: "G['torch']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'], 4351320976)"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 96:
#     Name: "L['value_shape']"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['value_shape'], 4891320080)", "len(L['value_shape']) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef100; to 'type' at 0x1238b9f10 (Size)>
#   Guard 97:
#     Name: "L['data']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['data'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a520; to 'Tensor' at 0x3048d9a80>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 98:
#     Name: "G['__builtins_dict___79']['type']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___79']['type'], 4305563712)"]
#     Object Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 99:
#     Name: "L['batch_shape']"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['batch_shape'], 4305555088)", "len(L['batch_shape']) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 100:
#     Name: "L['device']"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['device'] == device(type='cpu')"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104beffb0; to 'type' at 0x1238b8c48 (device)>
#   Guard 101:
#     Name: "G['__builtins_dict___79']['isinstance']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___79']['isinstance'], 4307013760)"]
#     Object Weakref: <weakref at 0x31eb406d0; to 'builtin_function_or_method' at 0x100b7d080>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 102:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 103:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 104:
#     Name: "G['__builtins_dict___79']['len']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___79']['len'], 4307014080)"]
#     Object Weakref: <weakref at 0x31eb4a9d0; to 'builtin_function_or_method' at 0x100b7d1c0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 105:
#     Name: "G['__import_torch_dot__dynamo_dot_polyfills'].types"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_torch_dot__dynamo_dot_polyfills'].types, 4308052752)"]
#     Object Weakref: <weakref at 0x31eb86de0; to 'module' at 0x100c7ab10>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 106:
#     Name: "G['__builtins_dict___79']['zip']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___79']['zip'], 4305487296)"]
#     Object Weakref: <weakref at 0x100b7c860; to 'type' at 0x100a085c0>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 107:
#     Name: "G['torch'].bool"
#     Source: global
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['torch'].bool == torch.bool"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef290; to 'type' at 0x1238b8de0 (dtype)>
#   Guard 108:
#     Name: "L['value_shape'][0]"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['value_shape'][0] == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 109:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 110:
#     Name: "L['data'].reshape"
#     Source: local
#     Create Function: HASATTR
#     Guard Types: ['HASATTR']
#     Code List: ["hasattr(L['data'], 'reshape')"]
#     Object Weakref: <weakref at 0x31eb4a520; to 'Tensor' at 0x3048d9a80>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 111:
#     Name: "G['__import_torch_dot__dynamo_dot_polyfills']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_torch_dot__dynamo_dot_polyfills'], 5486842384)"]
#     Object Weakref: <weakref at 0x31eb87b50; to 'module' at 0x1470a9210>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 112:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 113:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 114:
#     Name: "G['torch']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'], 4351320976)"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 115:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 116:
#     Name: "L['value_shape']"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['value_shape'], 4891320080)", "len(L['value_shape']) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef100; to 'type' at 0x1238b9f10 (Size)>
#   Guard 117:
#     Name: "L['___stack0']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['___stack0'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31e8b75b0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 118:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 119:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 120:
#     Name: "L['original_ndim']"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['original_ndim'] == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 121:
#     Name: "G['torch'].index_select"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'].index_select, 4428298288)"]
#     Object Weakref: <weakref at 0x31eb8c1d0; to 'builtin_function_or_method' at 0x107f27830>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 122:
#     Name: "L['batch_shape']"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['batch_shape'], 4305555088)", "len(L['batch_shape']) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 123:
#     Name: "L['flat_data']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['flat_data'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb86070; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 124:
#     Name: "L['value_shape'][0]"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['value_shape'][0] == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 125:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 126:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 127:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 128:
#     Name: "L['valid_states_idx']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['valid_states_idx'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb4a2a0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 129:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 130:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
# ...
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___125']['super'], 4305490664)"]
#     Object Weakref: <weakref at 0x100b42d40; to 'type' at 0x100a092e8>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 376:
#     Name: "G['__import_gfn_dot_states'].torch.Tensor"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'].torch.Tensor, 5106997584)"]
#     Object Weakref: <weakref at 0x1176e1b20; to '_TensorMeta' at 0x130669950>
#     Guarded Class Weakref: <weakref at 0x104bfcd10; to 'type' at 0x1238bcd38 (_TensorMeta)>
#   Guard 377:
#     Name: "L['self'].States.s0"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['self'].States.s0, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31d844ef0; to 'Tensor' at 0x12282a7a0>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 378:
#     Name: "G['__builtins_dict___125']['isinstance']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___125']['isinstance'], 4307013760)"]
#     Object Weakref: <weakref at 0x31eb406d0; to 'builtin_function_or_method' at 0x100b7d080>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 379:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 380:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 381:
#     Name: "L['states'].tensor"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['states'].tensor, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 382:
#     Name: "L['self'].States.sf.repeat"
#     Source: local
#     Create Function: HASATTR
#     Guard Types: ['HASATTR']
#     Code List: ["hasattr(L['self'].States.sf, 'repeat')"]
#     Object Weakref: <weakref at 0x31e973c90; to 'Tensor' at 0x147a2cbd0>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 383:
#     Name: "L['self'].States"
#     Source: local
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(L['self'].States, 6146094768)"]
#     Object Weakref: <weakref at 0x147c837e0; to 'ABCMeta' at 0x16e55f6b0>
#     Guarded Class Weakref: <weakref at 0x100c198f0; to 'type' at 0x14070bef0 (ABCMeta)>
#   Guard 384:
#     Name: "L['not_done_states'].tensor.scatter"
#     Source: local
#     Create Function: HASATTR
#     Guard Types: ['HASATTR']
#     Code List: ["hasattr(L['not_done_states'].tensor, 'scatter')"]
#     Object Weakref: <weakref at 0x31ebc49f0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 385:
#     Name: "L['self']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['self'], 6146079840)"]
#     Object Weakref: <weakref at 0x31eb4bab0; to 'HyperGrid' at 0x104aeb250>
#     Guarded Class Weakref: <weakref at 0x3048a2570; to 'ABCMeta' at 0x16e55bc60 (HyperGrid)>
#   Guard 386:
#     Name: "G['States']"
#     Source: global
#     Create Function: ID_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['States'], 6146032752)"]
#     Object Weakref: <weakref at 0x304871a30; to 'ABCMeta' at 0x16e550470>
#     Guarded Class Weakref: <weakref at 0x100c198f0; to 'type' at 0x14070bef0 (ABCMeta)>
#   Guard 387:
#     Name: "G['__import_gfn_dot_states'].torch.bool"
#     Source: global
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["G['__import_gfn_dot_states'].torch.bool == torch.bool"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef290; to 'type' at 0x1238b8de0 (dtype)>
#   Guard 388:
#     Name: "L['states']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['states'], 6146094768)"]
#     Object Weakref: <weakref at 0x30bb6aac0; dead>
#     Guarded Class Weakref: <weakref at 0x147c837e0; to 'ABCMeta' at 0x16e55f6b0 (DiscreteEnvStates)>
#   Guard 389:
#     Name: "L['states'].tensor"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['states'].tensor, 5106997584)"]
#     Object Weakref: <weakref at 0x31eac2ca0; to 'Tensor' at 0x3048d9a30>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 390:
#     Name: "L['self'].States.state_shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['self'].States.state_shape, 4305555088)", "len(L['self'].States.state_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 391:
#     Name: "L['states'].state_shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['states'].state_shape, 4305555088)", "len(L['states'].state_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 392:
#     Name: "L['new_valid_states_idx']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['new_valid_states_idx'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb0a7f0; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 393:
#     Name: "L['self'].States.sf"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['self'].States.sf, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31e973c90; to 'Tensor' at 0x147a2cbd0>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 394:
#     Name: "L['self'].States.n_actions"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['EQUALS_MATCH']
#     Code List: ["L['self'].States.n_actions == 3"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af24d0; to 'type' at 0x100a19ab8 (int)>
#   Guard 395:
#     Name: "G['__import_gfn_dot_states'].torch.ones"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__import_gfn_dot_states'].torch.ones, 4428225552)"]
#     Object Weakref: <weakref at 0x31eb40810; to 'builtin_function_or_method' at 0x107f15c10>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 396:
#     Name: "L['not_done_states']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['not_done_states'], 6146094768)"]
#     Object Weakref: <weakref at 0x31db73c90; dead>
#     Guarded Class Weakref: <weakref at 0x147c837e0; to 'ABCMeta' at 0x16e55f6b0 (DiscreteEnvStates)>
#   Guard 397:
#     Name: "L['___stack0'].tensor"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['___stack0'].tensor, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb55670; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 398:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 399:
#     Name: "L['states'].tensor.shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['states'].tensor.shape, 4891320080)", "len(L['states'].tensor.shape) == 2"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x104bef100; to 'type' at 0x1238b9f10 (Size)>
#   Guard 400:
#     Name: "G['__builtins_dict___125']['len']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___125']['len'], 4307014080)"]
#     Object Weakref: <weakref at 0x31eb4a9d0; to 'builtin_function_or_method' at 0x100b7d1c0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 401:
#     Name: "L['self'].tensor"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['self'].tensor, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31ed41d00; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 402:
#     Name: "G['torch'].zeros"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'].zeros, 4428230352)"]
#     Object Weakref: <weakref at 0x31db0ccc0; to 'builtin_function_or_method' at 0x107f16ed0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 403:
#     Name: "G['__builtins_dict___127']['tuple']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___127']['tuple'], 4305555088)"]
#     Object Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90>
#     Guarded Class Weakref: <weakref at 0x100af0ef0; to 'type' at 0x100a1b040 (type)>
#   Guard 404:
#     Name: ''
#     Source: shape_env
#     Create Function: SHAPE_ENV
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 405:
#     Name: ''
#     Source: global
#     Create Function: GRAD_MODE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 406:
#     Name: "G['torch']"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'], 4351320976)"]
#     Object Weakref: <weakref at 0x31eb40540; to 'module' at 0x1035be390>
#     Guarded Class Weakref: <weakref at 0x100b331a0; to 'type' at 0x100a0d408 (module)>
#   Guard 407:
#     Name: ''
#     Source: global
#     Create Function: DETERMINISTIC_ALGORITHMS
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 408:
#     Name: "L['cond']"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['cond'], '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31ea6be20; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 409:
#     Name: "L['self'].state_shape"
#     Source: local
#     Create Function: SEQUENCE_LENGTH
#     Guard Types: ['TYPE_MATCH', 'SEQUENCE_LENGTH']
#     Code List: ["___check_type_id(L['self'].state_shape, 4305555088)", "len(L['self'].state_shape) == 1"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100b43790; to 'type' at 0x100a18e90 (tuple)>
#   Guard 410:
#     Name: ''
#     Source: global
#     Create Function: AUTOGRAD_SAVED_TENSORS_HOOKS
#     Guard Types: ['AUTOGRAD_SAVED_TENSORS_HOOKS']
#     Code List: ['torch._functorch.aot_autograd.utils.top_saved_tensors_hooks ids == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 411:
#     Name: "L['self']"
#     Source: local
#     Create Function: TYPE_MATCH
#     Guard Types: ['TYPE_MATCH']
#     Code List: ["___check_type_id(L['self'], 6146094768)"]
#     Object Weakref: <weakref at 0x31eb57ce0; dead>
#     Guarded Class Weakref: <weakref at 0x147c837e0; to 'ABCMeta' at 0x16e55f6b0 (DiscreteEnvStates)>
#   Guard 412:
#     Name: "G['torch'].cat"
#     Source: global
#     Create Function: FUNCTION_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['torch'].cat, 4428310752)"]
#     Object Weakref: <weakref at 0x31e972750; to 'builtin_function_or_method' at 0x107f2a8e0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 413:
#     Name: ''
#     Source: global
#     Create Function: TORCH_FUNCTION_STATE
#     Guard Types: None
#     Code List: None
#     Object Weakref: None
#     Guarded Class Weakref: None
#   Guard 414:
#     Name: "L['allow_exit']"
#     Source: local
#     Create Function: CONSTANT_MATCH
#     Guard Types: ['BOOL_MATCH']
#     Code List: ["L['allow_exit'] == True"]
#     Object Weakref: None
#     Guarded Class Weakref: <weakref at 0x100af27a0; to 'type' at 0x100a19190 (bool)>
#   Guard 415:
#     Name: "L['self'].forward_masks"
#     Source: local
#     Create Function: TENSOR_MATCH
#     Guard Types: ['TENSOR_MATCH']
#     Code List: ["hasattr(L['self'].forward_masks, '_dynamo_dynamic_indices') == False"]
#     Object Weakref: <weakref at 0x31eb0b240; dead>
#     Guarded Class Weakref: <weakref at 0x1176e1b20; to 'torch._C._TensorMeta' at 0x130669950 (Tensor)>
#   Guard 416:
#     Name: "G['__builtins_dict___127']['len']"
#     Source: global
#     Create Function: BUILTIN_MATCH
#     Guard Types: ['ID_MATCH']
#     Code List: ["___check_obj_id(G['__builtins_dict___127']['len'], 4307014080)"]
#     Object Weakref: <weakref at 0x31eb4a9d0; to 'builtin_function_or_method' at 0x100b7d1c0>
#     Guarded Class Weakref: <weakref at 0x100b09cb0; to 'type' at 0x100a0a520 (builtin_function_or_method)>
#   Guard 417:
#     Name: ''
#     Source: global
#     Create Function: DEFAULT_DEVICE
#     Guard Types: ['DEFAULT_DEVICE']
#     Code List: ['utils_device.CURRENT_DEVICE == None']
#     Object Weakref: None
#     Guarded Class Weakref: None
# Compile Times: TorchDynamo compilation metrics:
# Function, Runtimes (s)
# _compile.compile_inner, 0.0755, 0.0391, 0.0135, 0.0140, 0.0205, 0.0074, 0.0033, 0.0027, 0.0187, 0.0188, 0.0175, 0.0315, 0.0340, 0.0261, 0.0341, 0.0167, 0.0232, 0.0155, 0.0428, 0.1327, 0.0327, 0.0096
# compile_attempt_0, 0.0499, 0.0194, 0.0083, 0.0081, 0.0069, 0.0045, 0.0030, 0.0024, 0.0108, 0.0124, 0.0096, 0.0136, 0.0277, 0.0127, 0.0168, 0.0121, 0.0115, 0.0118, 0.0223, 0.1121, 0.0279, 0.0063
# bytecode_tracing, 0.0484, 0.0159, 0.0188, 0.0110, 0.0079, 0.0011, 0.0077, 0.0016, 0.0064, 0.0053, 0.0027, 0.0026, 0.0020, 0.0103, 0.0001, 0.0118, 0.0013, 0.0092, 0.0019, 0.0131, 0.0104, 0.0253, 0.0122, 0.0045, 0.0161, 0.0096, 0.0101, 0.0110, 0.0038, 0.0096, 0.0218, 0.0104, 0.1115, 0.0103, 0.0242, 0.0044
# compile_attempt_1, 0.0200, 0.0156, 0.0023, 0.0028, 0.0097, 0.0051, 0.0035, 0.0043, 0.0127, 0.0090, 0.0120, 0.0081, 0.0161, 0.0166
# OutputGraph.call_user_compiler, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001
# build_guards, 0.0046, 0.0035, 0.0023, 0.0026, 0.0034, 0.0025, 0.0023, 0.0024, 0.0031, 0.0046, 0.0054, 0.0038, 0.0046, 0.0041, 0.0032, 0.0032, 0.0037, 0.0033, 0.0042, 0.0028
# gc, 0.0006, 0.0003, 0.0002, 0.0002, 0.0002, 0.0001, 0.0001, 0.0001, 0.0003, 0.0002, 0.0003, 0.0003, 0.0004, 0.0003, 0.0003, 0.0002, 0.0002, 0.0002, 0.0005, 0.0003, 0.0002, 0.0002
# pgo.dynamic_whitelist, 0.0000, 0.0000, 0.0000, 0.0000
